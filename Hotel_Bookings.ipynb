# %% [markdown]
# # Exploratory Data Analysis
# ### By: Bernard Evan Kanigara

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read Data

# %%
df=pd.read_csv('hotel_bookings.csv')

# %%
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Summary of the Data

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
len(df.index)
# Out:
# 119390

# %% [markdown]
# ### Checking the Missing Value

# %%
print(df.isnull().sum())
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# ### Cleaning the Data

# %%
ax = sns.countplot(x="children", data=df)

# %%
df['agent'].value_counts()
# Out:
# 9.0      31961
# 240.0    13922
# 1.0       7191
# 14.0      3640
# 7.0       3539
#          ...
# 289.0        1
# 432.0        1
# 265.0        1
# 93.0         1
# 304.0        1
# Name: agent, Length: 333, dtype: int64

# %%
df.country.value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: country, Length: 177, dtype: int64

# %% [markdown]
# ### Replacing the Missing Value
# - Missing value on 'Children' & 'Country' will be replaced with mode of each group.
# - While the 'Agent' and 'Company' will be dropped because there are too many missing value.

# %%
df['children'] = df['children'].fillna(0)
df['country'] = df['country'].fillna('PRT')
df = df.drop('agent', axis = 1)
df = df.drop('company', axis = 1)

# %%
print(df.isnull().sum())
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %% [markdown]
# ### Statistical Insight

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
corr=df.corr()
corr
# Out:
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.293123           0.016660
# lead_time                          0.293123   1.000000           0.040142
# arrival_date_year                  0.016660   0.040142           1.000000
# arrival_date_week_number           0.008148   0.126871          -0.540561
# arrival_date_day_of_month         -0.006130   0.002268          -0.000221
# stays_in_weekend_nights           -0.001791   0.085671           0.021497
# stays_in_week_nights               0.024765   0.165799           0.030883
# adults                             0.060017   0.119519           0.029635
# children                           0.005036  -0.037613           0.054636
# babies                            -0.032491  -0.020915          -0.013192
# is_repeated_guest                 -0.084793  -0.124410           0.010341
# previous_cancellations             0.110133   0.086042          -0.119822
# ...

# %%
f, ax = plt.subplots(figsize=(12, 10))
mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(df.corr(), annot=True,mask = mask, cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
ax = sns.boxplot(x="is_canceled", y="lead_time", data=df)

# %% [markdown]
# The more lead time spent, the more likely bookings will be canceled

# %%
sns.scatterplot(data=df, x="stays_in_weekend_nights", y="stays_in_week_nights")
# Out:
# <AxesSubplot:xlabel='stays_in_weekend_nights', ylabel='stays_in_week_nights'>

# %% [markdown]
# If customers book hotel rooms on multiple weekends, they'll also book weekdays, not just weekends.

# %% [markdown]
# ### Data Visualization & Insight

# %%
count = np.array([49078, 12129,10415,8568,7287,31913])
country = ['PRT','GBR','FRA','ESP','DEU','others']

plt.pie(count, labels = country)
plt.show()

# %% [markdown]
# Portuguese book the most hotel rooms

# %%
plt.xticks(rotation=45)
ax = sns.countplot(x="arrival_date_month", data=df)

# %% [markdown]
# Summer (July, August) are the busiest month, and the winter (December, January) are the most vacant

# %%
plt.xticks(rotation=45)
sns.countplot(data=df, x= 'market_segment')
# Out:
# <AxesSubplot:xlabel='market_segment', ylabel='count'>

# %% [markdown]
# Most people use Online TA to make a reservation of the hotel

# %%
plt.xticks(rotation=45)
sns.countplot(data=df, x= 'hotel',hue='is_canceled')
# Out:
# <AxesSubplot:xlabel='hotel', ylabel='count'>

# %% [markdown]
# The city hotel type are likely to face more cancelation than the resort hotel

# %%
plt.xticks(rotation=45)
sns.lineplot(data=df, x="arrival_date_year", y="adr")
# Out:
# <AxesSubplot:xlabel='arrival_date_year', ylabel='adr'>

# %% [markdown]
# The hotel revenue (adr) increase every year

# %%
plt.xticks(rotation=45)
sns.lineplot(data=df, x="arrival_date_month", y="adr", hue="hotel")
# Out:
# <AxesSubplot:xlabel='arrival_date_month', ylabel='adr'>

# %% [markdown]
# Hotel revenue/prices (adr) will more likely increase in resort hotels rather than city hotels.
